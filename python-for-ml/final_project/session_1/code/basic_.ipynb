# %%
list_one = [1, 2, 3, "amit", "learning", True, ["ml", "dl", "cv", "nlp"]]

# %%
list_one[4]
# Out:
# 'learning'

# %%
list_one[6][0]
# Out:
# 'ml'

# %%
list_one[6][0]="ds"
list_one
# Out:
# [1, 2, 3, 'amit', 'learning', True, ['ds', 'dl', 'cv', 'nlp']]

# %%
list_1=["depi", "learning", "ml"]
list_1.append("dl")
list_1
# Out:
# ['depi', 'learning', 'ml', 'dl']
