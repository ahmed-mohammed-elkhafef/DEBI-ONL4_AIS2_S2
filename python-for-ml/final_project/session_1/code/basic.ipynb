# %%
# comment
'''
coments
coments
coments
coments

'''
# Out:
# '\ncoments\ncoments\ncoments\ncoments\n\n'

# %%
name= "Ahmed"
age= 22
course="AI"
print("my name is {} and my age is {}".format("Ahmed",22))
print("my name is {1} and my age is {0}".format("Ahmed",22))
print("my name is {} and my age is {}".format(name,age))
print(f"my name is {name} and my age is {age}")
# Out:
# my name is Ahmed and my age is 22
# my name is 22 and my age is Ahmed
# my name is Ahmed and my age is 22
# my name is Ahmed and my age is 22

# %%
print(f"my name is {name} , and my age is {age} , my enrooled course is {course}")
# Out:
# my name is Ahmed , and my age is 22 , my enrooled course is AI

# %%
print(type(name))
print(type(age))
print(type(course))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'str'>

# %%
amit= "amit learning"
amit[0:8:2]
# Out:
# 'ai e'

# %%
upper_text=amit.upper()
print(upper_text)
lower_text=upper_text.lower()
print(lower_text)
replaced_text=amit.replace("amit","ml")
print(replaced_text)
# Out:
# AMIT LEARNING
# amit learning
# ml learning

# %%
amit.count("l")
# Out:
# 1

# %%
x=amit.split()
x
# Out:
# ['amit', 'learning']

# %%
response= ' '.join(x)
print(response)
# Out:
# amit learning

# %%
response.startswith("d")
# Out:
# False
