# %%
list_one = [1, 2, 3, "amit", "learning", True, ["ml", "dl", "cv", "nlp"]]

# %%
list_one[4]
# Out:
# 'learning'

# %%
list_one[6][0]
# Out:
# 'ml'

# %%
list_one[6][0]="ds"
list_one
# Out:
# [1, 2, 3, 'amit', 'learning', True, ['ds', 'dl', 'cv', 'nlp']]

# %%
list_1=["depi", "learning", "ml"]
list_1.append("dl")
list_1
# Out:
# ['depi', 'learning', 'ml', 'dl']

# %%
list_1.insert(0,"ds")
list_1
# Out:
# ['ds', 'depi', 'learning', 'ml', 'dl']

# %%
list_2=[1, 2, 3]
list_3=[4, 5, 6]
list_2 + list_3
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
list_2
# Out:
# [1, 2, 3]

# %%
list_2.extend(list_3)
list_2
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
x=5
del x
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 3
#       1 x=5
#       2 del x
# ----> 3 x
#
# NameError: name 'x' is not defined

# %%
list_2.remove(5)
list_2
# Out:
# [1, 2, 3, 4, 6]

# %%
list_2.pop()
list_2
# Out:
# [1, 2, 3, 4]

# %%
list_2.pop(0)
list_2
# Out:
# [2, 3, 4]

# %%
del list_2[0]
list_2
# Out:
# [3, 4]

# %%
lst1=[1, 2, 3]
lst2=[4, 5, 6]
lst3=[7, 8, 9]

matrix=[lst1, lst2, lst3]
matrix
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
lst=["one", "two", "three", 4.6]
lst[:]
# Out:
# ['one', 'two', 'three', 4.6]

# %%
lst*2
# Out:
# ['one', 'two', 'three', 4.6, 'one', 'two', 'three', 4.6]

# %%
name= input("Enter your name")
name
# Out:
# '5'

# %%
type(name)
# Out:
# str

# %%
name_= input("Enter your name")
id=input("enter your id ")
print(f"my name is {name_}, my id is {id}")
# Out:
# my name is Ahmed, my id is 201

# %%
input_list=["depi", "learnng", "python"]
item= input("Enter values")
input_list.remove(item)
print(f"output list {input_list}")
# Out:
# output list ['learnng', 'python']

# %%
my_lst= [1, 2, 3, 3]
index_val= my_lst.index(3)
index_val
# Out:
# 2

# %%
index_val= my_lst.index(4)
index_val
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 index_val= my_lst.index(4)
#       2 index_val
#
# ValueError: 4 is not in list

# %%
my_lst.count(3)
# Out:
# 2

# %%
list_sort=[1,5,8,4,3,6,7,0,1]
list_sort.sort()
list_sort
# Out:
# [0, 1, 1, 3, 4, 5, 6, 7, 8]

# %%
list_sort.clear()
list_sort
# Out:
# []

# %%
tuple1=(1, 2, 3)
# tuple1[1]="depi" #False
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 2
#       1 tuple1=(1, 2, 3)
# ----> 2 tuple1[1]="depi"
#
# TypeError: 'tuple' object does not support item assignment

# %%
nm = "depi"
tuple(nm)
# Out:
# ('d', 'e', 'p', 'i')

# %%
tuple1=list(tuple1)
tuple1[0]="depi"
tuple(tuple1)
# Out:
# ('depi', 2, 3)

# %%
set1={"depi", "learning"}
# set1[0] #False
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 2
#       1 set1={"depi", "learning"}
# ----> 2 set1[0]
#
# TypeError: 'set' object is not subscriptable

# %%
color={"red", "green", "blue"}
color.remove("green")
color
# Out:
# {'blue', 'red'}

# %%
color.discard("red")
color
# Out:
# {'blue'}

# %%
a={1, 2, 3}
b={3, 4, 5}
a.intersection(b)
# Out:
# {3}

# %%
a.union(b)
# Out:
# {1, 2, 3, 4, 5}

# %%
a.difference(b)
# Out:
# {1, 2}

# %%
dct1={"key1":12.5}
type(dct1)
# Out:
# dict

# %%
dct1["key1"]="depi"
dct1
# Out:
# {'key1': 'depi'}

# %%
x=int(input("enter num one"))
y=int(input("enter num two"))

print(f"{x} + {y} = {x+y}")
print(f"{x} * {y} = {x*y}")
print(f"{x} / {y} = {x/y}")
print(f"{x} - {y} = {x-y}")
# Out:
# 8 + 6 = 14
# 8 * 6 = 48
# 8 / 6 = 1.3333333333333333
# 8 - 6 = 2

# %%
a=200
b=33

if b>a:
    print("b is greater than a")
else:
    print("b is not greater than a")
# Out:
# b is not greater than a

# %%
x=5
y=10
if x>0 and y>0:
    print("positive numbers")
# Out:
# positive numbers

# %%
x= 5
"Even" if x%2==0 else "odd"
# Out:
# 'odd'

# %%
a=10
b=5
result= a+b  if a>b else a-b
print(result)
# Out:
# 15

# %%
age= 12
print("adult") if age>=18 else (print("teenager") if age >=13 else print("child"))
# Out:
# child

# %%
is_sunny=True
tem=25
if is_sunny :
    print("sunny day")
    if tem>20:
        print("warm")
    else:
        print("cool")
else: 
    print("not sunny day")
# Out:
# sunny day
# warm

# %%
degree= int(input("Enter your grade"))
if degree >=0 and degree<=100:
    if degree>=90:
        grade="A"
    elif degree>=80:
        grade="B"
    elif degree>=70:
        grade="C"
    elif degree>=60:
        grade="D"
    else :
        grade="F"
    print(grade)   
else:
    print("invalid input, degree must be betwwen 0 and 100")
# Out:
# A

# %%
for i in range(6):
    if i==3:
        break
    print(i)
# Out:
# 0
# 1
# 2

# %%
for i in range(6):
    if i==3:
        continue
    print(i)
# Out:
# 0
# 1
# 2
# 4
# 5

# %%
for i in range(6):
    if i==3:
        pass
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
x=6
while x>0:
    print("python")
    x-=1
# Out:
# python
# python
# python
# python
# python
# python
