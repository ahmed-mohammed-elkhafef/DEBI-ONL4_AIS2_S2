# %%
import os
import random as rd

# %%
def file():
    dir = "D:/01_ENV_AI/DEBI-ONL4/DEBI-ONL4_AIS2_S2/python-for-ml/final_project/session_3/asssignment/handling_file_task"
    os.makedirs(dir)
    for i in range(20):
        with open(f"{dir}/file_{i}.txt","a+"):
            pass
    files=os.listdir(dir)
    print(files)
    print(f"befor: {len(files)}")
    for i in rd.sample(range(0,20),10):
        os.remove(f"{dir}/file_{i}.txt")
    files=os.listdir(dir)
    print(files)
    print(f"after: {len(files)}")
file()
# Out:
# ['file_0.txt', 'file_1.txt', 'file_10.txt', 'file_11.txt', 'file_12.txt', 'file_13.txt', 'file_14.txt', 'file_15.txt', 'file_16.txt', 'file_17.txt', 'file_18.txt', 'file_19.txt', 'file_2.txt', 'file_3.txt', 'file_4.txt', 'file_5.txt', 'file_6.txt', 'file_7.txt', 'file_8.txt', 'file_9.txt']
# befor: 20
# ['file_0.txt', 'file_10.txt', 'file_13.txt', 'file_14.txt', 'file_15.txt', 'file_17.txt', 'file_19.txt', 'file_2.txt', 'file_3.txt', 'file_5.txt']
# after: 10
