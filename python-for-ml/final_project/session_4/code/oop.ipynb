# %%
class StudentInfo:


    student_name = "Ahmed"
    student_age = 22
    gpa = 3.2
    gender = "male"

    def student_info(self):
        return f"welcome to Depi problems"

    def sum():
        pass

    def sub():
        pass

# %%
s1 = StudentInfo()
s1.student_name
# Out:
# 'Ahmed'

# %%
s1.student_name = "Mohamed"
s1.student_name
# Out:
# 'Mohamed'

# %%
s1.student_info()
# Out:
# 'welcome to Depi problems'

# %%
class StudentInfo2:


    student_name = "Ahmed"
    student_age = 22
    gpa = 3.2
    gender = "male"

    def student_info(self):
        print(self)

# %%
s2 = StudentInfo2()
print(s2)
print(s2.student_info())
# Out:
# ...
# None

# %%
class StudentInfo3:

    def __init__(self, name = "Ahmed", age = 22):
        self.name=name
        self.age=age
        

    def student_info(self):
        return self.name, self.age

# %%
s3 = StudentInfo3()
print(s3.student_info())
# Out:
# ('Ahmed', 22)

# %%
s3 = StudentInfo3("mohamed", 44)
print(s3.student_info())
# Out:
# ('mohamed', 44)

# %%
from abc import ABC, abstractmethod

class Animal(ABC):

    @abstractmethod
    def move(self):
        pass

class Bird(Animal):


    def move(self):
        print("move from bird")

class Cat(Animal):

    def move(self):
        print("move from cat")

# %%
a=Bird()
a.move()
# Out:
# move from bird

# %%
a=Animal()
a.move()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 a=Animal()
#       2 a.move()
#
# TypeError: Can't instantiate abstract class Animal without an implementation for abstract method 'move'

# %%
class A():

    def do_this(self):
        print("I am in A")

class B(A):
    pass

class C():
    def do_this(self):
        print("I am in C")

class D(B,C):
    pass

x=D()
x.do_this()
# Out:
# I am in A

# %%
class A():

    def do_this(self):
        print("I am in A")

class B(A):
    pass

class C():
    def do_this(self):
        print("I am in C")

class D(C,D):
    pass

x=D()
x.do_this()
# Out:
# I am in C
